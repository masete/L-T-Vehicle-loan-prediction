# %%
import pandas as pd

# %%
data = pd.read_csv('data/clean_data.csv')

# %%
data.head()
# Out:
#    UNIQUEID  DISBURSED_AMOUNT  ASSET_COST       LTV  BRANCH_ID  SUPPLIER_ID  \
# 0    420825          0.439324    0.230606  0.875911         67        22807
# 1    417566          0.490280    0.289956  0.877732         67        22807
# 2    539055          0.473295    0.268703  0.849499         67        22807
# 3    518279          0.513588    0.300784  0.878415         67        22807
# 4    529269          0.359510    0.292764  0.576958         67        22807
#
#    MANUFACTURER_ID  CURRENT_PINCODE_ID  EMPLOYMENT_TYPE DISBURSAL_DATE  ...  \
# 0               45                1441                1     2018-03-08  ...
# 1               45                1497                2     2018-01-08  ...
# 2               45                1495                2     2018-09-26  ...
# 3               45                1501                2     2018-09-19  ...
# 4               45                1502                1     2018-09-23  ...
#
# ...

# %%
data['NEW_ACCTS_IN_LAST_SIX_MONTHS'].unique()
# Out:
# array([ 0,  1,  2,  3,  4,  5,  7, 20,  8])

# %% [markdown]
# ### feature selection
